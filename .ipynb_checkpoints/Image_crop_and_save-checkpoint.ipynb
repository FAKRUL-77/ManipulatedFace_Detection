# %%
import os
import dlib
from mtcnn import MTCNN
import numpy as np

manipulate_path = 'manipulated_sequences/FaceShifter/'
original_path = 'original_sequences/'

mvd = os.walk(manipulate_path)
manipulated_data = []
original_data = []
import os
for root, dirs, files in os.walk(manipulate_path, topdown=False):
   for name in files:
      directory = os.path.join(root, name)
      manipulated_data.append(directory)

for root, dirs, files in os.walk(original_path, topdown=False):
   for name in files:
      directory = os.path.join(root, name)
      original_data.append(directory)

# %%
# def image_crop(video, i):
#     detector = MTCNN()
#     cap = cv2.VideoCapture(video)
#     def getFrame(sec):
#         cap.set(cv2.CAP_PROP_POS_MSEC, sec*1000)
#         hasFrames, image = cap.read()
#         result = detector.detect_faces(image)
        
#         box = result[0]['box']
# #         print(keypoints)
        
#         if hasFrames:
#             face = image[box[1]:box[1]+box[3], box[0]:box[0]+box[2]]
# #             print(face, box[0], box[1], box[2], box[3])
            
#             cv2.imwrite('original/original_' + str(i) + '_video_' + str(count) + '.jpg', face)
# #             cv2.imwrite('original/original_' + str(i) + '_video_' + str(count) + '.jpg', keypoints)
#         return hasFrames
#     sec = 0.3
#     count = 1
#     frameRate = 1
#     success = getFrame(sec)
    
#     while success:
#         count += 1
#         sec += frameRate
#         sec = round(sec, 2)
#         success = getFrame(sec)
#     i += 1

# %%
# img_size = 64
# margin = 0.2
# frame_count = 0
# def image_crop(video, i):
#     detector = dlib.get_frontal_face_detector()
#     cap = cv2.VideoCapture(video)
#     def getFrame(sec):
#         cap.set(cv2.CAP_PROP_POS_MSEC, sec*1000)
#         hasFrames, image = cap.read()
#         img_h, img_w, _ = np.shape(image)
#         if hasFrames:
#             detected = detector(image, 1)
#             if len(detected) > 0:
#                 for j, d in enumerate(detected):
#                     x1, y1, x2, y2, w, h = d.left(), d.top(), d.right() + 1, d.bottom() + 1, d.width(), d.height()
#                     xw1 = max(int(x1 - margin * w), 0)
#                     yw1 = max(int(y1 - margin * h), 0)
#                     xw2 = min(int(x2 + margin * w), img_w - 1)
#                     yw2 = min(int(y2 + margin * h), img_h - 1)
#                     face =  image[yw1:yw2 + 1, xw1:xw2 + 1]

#                     cv2.imwrite('manipulated/DeepFakeDetection_' + str(i) + '_video_' + str(count) + '.jpg', face)
#         return hasFrames
#     sec = 1
#     count = 1
#     frameRate = 1
#     success = getFrame(sec)

#     while success:
#         count += 1
#         sec += frameRate
#         sec = round(sec, 2)
#         success = getFrame(sec) 
#     cap.release()
#     cv2.destroyAllWindows()
#     i += 1

# %%
import cv2
img_size = 64
margin = 0.2
frame_count = 0
def image_crop(video, i):
    detector = dlib.get_frontal_face_detector()
    vidcap = cv2.VideoCapture(video)
    def getFrame(sec):
        vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
        hasFrames,image = vidcap.read()
        if hasFrames:
            detected = detector(image, 1)
            length = len(detected)
            img_h, img_w, _ = np.shape(image)
            if length > 0:
                for j, d in enumerate(detected):
                    x1, y1, x2, y2, w, h = d.left(), d.top(), d.right() + 1, d.bottom() + 1, d.width(), d.height()
                    xw1 = max(int(x1 - margin * w), 0)
                    yw1 = max(int(y1 - margin * h), 0)
                    xw2 = min(int(x2 + margin * w), img_w - 1)
                    yw2 = min(int(y2 + margin * h), img_h - 1)
                    face =  image[yw1:yw2 + 1, xw1:xw2 + 1]
                    
                    cv2.imwrite('manipulated/FaceShifter_' + str(i) + '_video_' + str(count) + '.jpg', face)
        return hasFrames
    sec = 0
    frameRate = 0.4 #//it will capture image in each 0.5 second
    count=1
    success = getFrame(sec)
    while success:
        count = count + 1
        sec = sec + frameRate
        sec = round(sec, 2)
        success = getFrame(sec)

# %%
i = 1
for video in manipulated_data:
    image_crop(video, i)
    i += 1
